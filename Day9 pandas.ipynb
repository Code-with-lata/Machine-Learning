# %%
import pandas as pd
csv_1 = pd.read_csv("Data.csv")
csv_1
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
# Out:
#     France    44    72000   No
# 0    Spain  27.0  48000.0  Yes
# 1    Spain  38.0  61000.0   No
# 2  Germany  40.0      NaN  Yes
# 3   France  35.0  58000.0  Yes
# 4    Spain   NaN  52000.0   No

# %%
import pandas as pd
csv_1 = pd.read_csv("Data.csv",nrows=3)
csv_1
# Out:
#    Country  Age  Salary Purchased
# 0   France   44   72000        No
# 1    Spain   27   48000       Yes
# 2  Germany   30   54000        No

# %%
import pandas as pd
csv_1 = pd.read_csv("Data.csv",usecols=["Country","Age"])#[0,2]
csv_1
# Out:
#    Country   Age
# 0   France  44.0
# 1    Spain  27.0
# 2  Germany  30.0
# 3    Spain  38.0
# 4  Germany  40.0
# 5   France  35.0
# 6    Spain   NaN
# 7   France  48.0
# 8  Germany  50.0
# 9   France  37.0

# %%
import pandas as pd
csv_1 = pd.read_csv("Data.csv",skiprows=[0,3])
csv_1
# Out:
#     France    44    72000   No
# 0    Spain  27.0  48000.0  Yes
# 1    Spain  38.0  61000.0   No
# 2  Germany  40.0      NaN  Yes
# 3   France  35.0  58000.0  Yes
# 4    Spain   NaN  52000.0   No
# 5   France  48.0  79000.0  Yes
# 6  Germany  50.0  83000.0   No
# 7   France  37.0  67000.0  Yes

# %%
csv_1[0:5:1]
# Out:
#     France    44    72000   No
# 0    Spain  27.0  48000.0  Yes
# 1    Spain  38.0  61000.0   No
# 2  Germany  40.0      NaN  Yes
# 3   France  35.0  58000.0  Yes
# 4    Spain   NaN  52000.0   No

# %%
csv_1[0:5:1]
# Out:
#     France    44    72000   No
# 0    Spain  27.0  48000.0  Yes
# 1    Spain  38.0  61000.0   No
# 2  Germany  40.0      NaN  Yes
# 3   France  35.0  58000.0  Yes
# 4    Spain   NaN  52000.0   No

# %%
csv_1.columns
# Out:
# Index(['France', '44', '72000', 'No'], dtype='object')

# %%
csv_1.describe()
# Out:
#               44         72000
# count   7.000000      7.000000
# mean   39.285714  64000.000000
# std     7.825477  13165.611772
# min    27.000000  48000.000000
# 25%    36.000000  55000.000000
# 50%    38.000000  61000.000000
# 75%    44.000000  73000.000000
# max    50.000000  83000.000000

# %%
csv_1.head(3)
# Out:
#     France    44    72000   No
# 0    Spain  27.0  48000.0  Yes
# 1    Spain  38.0  61000.0   No
# 2  Germany  40.0      NaN  Yes

# %%
csv_1.tail(3)
# Out:
#     France    44    72000   No
# 5   France  48.0  79000.0  Yes
# 6  Germany  50.0  83000.0   No
# 7   France  37.0  67000.0  Yes

# %%
csv_1.loc[0,"Country"]= "python"#location[row]
csv_1
# Out:
#    Country   Age   Salary Purchased
# 0   python  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
csv_1.loc[[2,4],["Country","Age"]]
# Out:
#    Country   Age
# 2  Germany  30.0
# 4  Germany  40.0

# %%
csv_1.loc[[2,4],:]
# Out:
#    Country   Age   Salary Purchased
# 2  Germany  30.0  54000.0        No
# 4  Germany  40.0      NaN       Yes

# %%
csv_1.iloc[0,1]#[row index,column index]
# Out:
# 44.0

# %%
csv_1.iloc[0,:]#show all the rows data
# Out:
# Country       python
# Age             44.0
# Salary       72000.0
# Purchased         No
# Name: 0, dtype: object

# %%
csv_1.iloc[0,:-1] #remove the last row data
# Out:
# Country     python
# Age           44.0
# Salary     72000.0
# Name: 0, dtype: object

# %%
csv_1.iloc[:,:-1]
# Out:
#    Country   Age   Salary
# 0   python  44.0  72000.0
# 1    Spain  27.0  48000.0
# 2  Germany  30.0  54000.0
# 3    Spain  38.0  61000.0
# 4  Germany  40.0      NaN
# 5   France  35.0  58000.0
# 6    Spain   NaN  52000.0
# 7   France  48.0  79000.0
# 8  Germany  50.0  83000.0
# 9   France  37.0  67000.0
